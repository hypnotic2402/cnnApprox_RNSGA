# %%
import numpy as np
from pymoo.core.problem import Problem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.repair.rounding import RoundingRepair
from pymoo.operators.sampling.rnd import IntegerRandomSampling
from pymoo.algorithms.moo.rnsga2 import RNSGA2

def combineBatches():
    a04 = np.load('tmp4a04.npy')
    a49 = np.load('tmp4a49.npy')
    b04 = np.load('tmp4b04.npy')
    c04 = np.load('tmp4c04.npy')
    d04 = np.load('tmp4d04.npy')
    e04 = np.load('tmp4e04.npy')
    f04 = np.load('tmp4f04.npy')
    g04 = np.load('tmp4g04.npy')
    h04 = np.load('tmp4h04.npy')
    i04 = np.load('tmp4i04.npy')
    b49 = np.load('tmp4b49.npy')
    c49 = np.load('tmp4c49.npy')
    d49 = np.load('tmp4d49.npy')
    e49 = np.load('tmp4e49.npy')
    f49 = np.load('tmp4f49.npy')
    g49 = np.load('tmp4g49.npy')
    h49 = np.load('tmp4h49.npy')
    i49 = np.load('tmp4i49.npy')

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[1][x][y][z][w] = b04[1][x][y][z][w]

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[2][x][y][z][w] = c04[2][x][y][z][w]
    
    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[3][x][y][z][w] = d04[3][x][y][z][w]

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[4][x][y][z][w] = e04[4][x][y][z][w]
    
    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[5][x][y][z][w] = f04[5][x][y][z][w]

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[6][x][y][z][w] = g04[6][x][y][z][w]

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[7][x][y][z][w] = h04[7][x][y][z][w]

    for x in range(0,4):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[8][x][y][z][w] = i04[8][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[0][x][y][z][w] = a49[0][x][y][z][w]
    
    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[1][x][y][z][w] = b49[1][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[2][x][y][z][w] = c49[2][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[3][x][y][z][w] = d49[3][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[4][x][y][z][w] = e49[4][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[5][x][y][z][w] = f49[5][x][y][z][w]

    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[6][x][y][z][w] = g49[6][x][y][z][w]
    
    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[7][x][y][z][w] = h49[7][x][y][z][w]
    
    for x in range(4,9):
        for y in range(0,9):
            for z in range(0,9):
                for w in range(0,9):
                    a04[8][x][y][z][w] = i49[8][x][y][z][w]

    

                

    
    return a04

# %%
def power(x):
    z = np.load('powerTable5l.npy')
    return z[int(np.floor(x[0]))][int(np.floor(x[1]))][int(np.floor(x[2]))][int(np.floor(x[3]))][int(np.floor(x[4]))]

def delay(x):
    z = np.load('delayTable5l.npy')
    return z[int(np.floor(x[0]))][int(np.floor(x[1]))][int(np.floor(x[2]))][int(np.floor(x[3]))][int(np.floor(x[4]))]

def errorAcc(x):
    # z = np.load('tmp1.npy')
    z = combineBatches()
    return z[int(np.floor(x[0]))][int(np.floor(x[1]))][int(np.floor(x[2]))][int(np.floor(x[3]))][int(np.floor(x[4]))]



def pdp(x):
    return power(x)*delay(x)

def area(x):
    ref = [358.758 , 353.286,366.966 ,372.096 , 363.546 , 371.754 , 353.97 , 345.42 , 578]
    done = []
    ar = 0
    for i in range(len(x)):
        if (x[i] not in done) :
            ar += ref[int(x[i])]
            done.append(x[i]) 
    
    return ar

def combinedFunc(x):
    return np.array([ pdp(x) , area(x),errorAcc(x) ])

# %%
class MyProblen(Problem):
    def __init__(self):
        super().__init__(n_var=5 ,  n_obj = 3 , xl = 0 , xu = 8 , vtype=int)

    def _evaluate(self, designs, out, *args, **kwargs):
        # out["F"] = np.column_stack([])
        res = []
        for design in designs:
            res.append(combinedFunc(design))

        out["F"] = np.array(res)

problem = MyProblen()

# %%
import pandas as pd

def generate_permutations(arrays, n):
    def backtrack(curr_permutation, index):
        if len(curr_permutation) == n:
            permutations.append(curr_permutation[:])
            return

        current_array = arrays[index]
        for element in current_array:
            curr_permutation.append(element)
            backtrack(curr_permutation, index + 1)
            curr_permutation.pop()

    permutations = []
    backtrack([], 0)
    return permutations

def genRefPoints(problem , k=2):
    sl = pd.read_csv("randomSensTest_l5.csv").to_numpy().T[1:].T
    rpIdx = []
    for layer in sl:
        l = np.argsort(layer)
        bestIdx = []
        for i in range(k):
            bestIdx.append(l[-1-i])
        rpIdx.append(bestIdx)
    ptsX = generate_permutations(rpIdx , problem.n_var)
    ptsF = []

    for x in ptsX:
        ptsF.append(combinedFunc(x))
    return np.array(ptsF)

# %%
algorithm = RNSGA2(
    ref_points=genRefPoints(problem , k=2),
    pop_size=100,
    epsilon=0.01,
    normalization='front',
    extreme_points_as_reference_points=False, sampling=IntegerRandomSampling() , crossover=SBX(eta = 1,vtype=float, repair=RoundingRepair()) , mutation=PolynomialMutation(eta = 5,vtype=float, repair=RoundingRepair()))

# %%
errorAcc([0,0,0,0,0])
# Out:
# 0.0

# %%
stop_criteria = ('n_gen' , 100)

results = minimize(problem=problem , algorithm=algorithm, termination=stop_criteria , verbose=True , save_history = True)
print(results.X)
print(results.F)
# Out:
# ...
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ...
#      1 |      100 |      4 |             - |             -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 stop_criteria = ('n_gen' , 100)
# ----> 3 results = minimize(problem=problem , algorithm=algorithm, termination=stop_criteria , verbose=True , save_history = True)
#       4 print(results.X)
#       5 print(results.F)
#
# File /usr/local/lib/python3.8/dist-packages/pymoo/optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# ...

# %%
Scatter(tight_layout = True, labels = ['PDP', 'Area', 'Error in Accuracy']).add(results.F).show()

# %%
# !pip3 install tqdm
# Out:
# ...
#      |████████████████████████████████| 78 kB 1.2 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm

pdp_all = []
erracc_all = []
area_all = []

for i in tqdm(range(0, 9)):
    for j in range(0, 9):
        for k in range(0, 9):
            for l in range(0, 9):
                for m in range(0, 9):
                    pdp_all.append(pdp([i, j, k, l, m]))
                    erracc_all.append(errorAcc([i, j, k, l, m]))
                    area_all.append(area([i, j, k, l, m]))
# Out:
# 100%|██████████| 9/9 [57:24<00:00, 382.73s/it]

# %%
plt.scatter(pdp_all, erracc_all, s=4)
plt.scatter(results.F[:, 0], results.F[:, 2], s=8, color='red')

# %%
plt.scatter(area_all, erracc_all, s=4)
plt.scatter(results.F[:, 1], results.F[:, 2], s=8, color='red')

# %%
pdp_all = np.array(pdp_all)
area_all = np.array(area_all)
erracc_all = np.array(erracc_all)

pdp_all = pdp_all.reshape(pdp_all.shape[0], 1)
area_all = area_all.reshape(pdp_all.shape[0], 1)
erracc_all = erracc_all.reshape(pdp_all.shape[0], 1)

all_f = np.append(pdp_all, area_all, axis=1)
all_f = np.append(all_f, erracc_all, axis=1)
# [pdp_all, area_all, erracc_all]
all_f.shape
# Out:
# (59049, 3)

# %%
np.save('all_f_l5.npy', all_f)

# %%
plot = Scatter(tight_layout = True, labels = ['PDP', 'Area', 'Error in Accuracy']).add(all_f, s=3)
plot.add(results.F, color='red').show()
# plot.show()

# %%
np.save("RNSGA2_l5_PDPvsAREA_X.npy" , results.X)
np.save("RNSGA2_l5_PDPvsAREA_F.npy" , results.F)
